# %% [markdown]
# # Challenge 1 - Tic Tac Toe
#
# In this lab you will perform deep learning analysis on a dataset of playing [Tic Tac Toe](https://en.wikipedia.org/wiki/Tic-tac-toe).
#
# There are 9 grids in Tic Tac Toe that are coded as the following picture shows:
#
# ![Tic Tac Toe Grids](tttboard.jpg)
#
# In the first 9 columns of the dataset you can find which marks (`x` or `o`) exist in the grids. If there is no mark in a certain grid, it is labeled as `b`. The last column is `class` which tells you whether Player X (who always moves first in Tic Tac Toe) wins in this configuration. Note that when `class` has the value `False`, it means either Player O wins the game or it ends up as a draw.

# %% [markdown]
# Follow the steps suggested below to conduct a neural network analysis using Tensorflow and Keras. You will build a deep learning model to predict whether Player X wins the game or not.
#
# ## Step 1: Data Engineering
#
# This dataset is almost in the ready-to-use state so you do not need to worry about missing values and so on. Still, some simple data engineering is needed.
#
# 1. Read `tic-tac-toe.csv` into a dataframe.
# 1. Inspect the dataset. Determine if the dataset is reliable by eyeballing the data.
# 1. Convert the categorical values to numeric in all columns.
# 1. Separate the inputs and output.
# 1. Normalize the input data.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# Step 1: Load the dataset
data = pd.read_csv(r"C:\Users\harid\Downloads\tic-tac-toe.csv")

# Step 2: Inspect the dataset
print(data.head())
print(data.info())

# Step 3: Convert categorical values to numeric
label_encoder = LabelEncoder()
data = data.apply(label_encoder.fit_transform)

# Step 4: Separate inputs and output
X = data.drop('class', axis=1)
y = data['class']

# Step 5: Normalize the input data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

print("Data engineering completed.")
# Out:
#   TL TM TR ML MM MR BL BM BR  class
# 0  x  x  x  x  o  o  x  o  o   True
# 1  x  x  x  x  o  o  o  x  o   True
# 2  x  x  x  x  o  o  o  o  x   True
# 3  x  x  x  x  o  o  o  b  b   True
# 4  x  x  x  x  o  o  b  o  b   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TL      958 non-null    object
#  1   TM      958 non-null    object
#  2   TR      958 non-null    object
#  3   ML      958 non-null    object
#  4   MM      958 non-null    object
#  5   MR      958 non-null    object
#  6   BL      958 non-null    object
#  7   BM      958 non-null    object
#  8   BR      958 non-null    object
#  9   class   958 non-null    bool
# dtypes: bool(1), object(9)
# memory usage: 68.4+ KB
# None
# Data engineering completed.

# %% [markdown]
# ## Step 2: Build Neural Network
#
# To build the neural network, you can refer to your own codes you wrote while following the [Deep Learning with Python, TensorFlow, and Keras tutorial](https://www.youtube.com/watch?v=wQ8BIBpya2k) in the lesson. It's pretty similar to what you will be doing in this lab.
#
# 1. Split the training and test data.
# 1. Create a `Sequential` model.
# 1. Add several layers to your model. Make sure you use ReLU as the activation function for the middle layers. Use Softmax for the output layer because each output has a single lable and all the label probabilities add up to 1.
# 1. Compile the model using `adam` as the optimizer and `sparse_categorical_crossentropy` as the loss function. For metrics, use `accuracy` for now.
# 1. Fit the training data.
# 1. Evaluate your neural network model with the test data.
# 1. Save your model as `tic-tac-toe.model`.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# Step 1: Split the training and test data
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Step 2: Create a Sequential model
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(2, activation='softmax')  # Assuming binary classification with two classes
])

# Step 3: Compile the model
model.compile(optimizer=Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Step 4: Fit the training data
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.2)

# Step 5: Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

# Step 6: Save the model with the .keras extension
model.save('tic-tac-toe.keras')

print("Model training and saving completed.")
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5697 - loss: 0.6744 - val_accuracy: 0.6753 - val_loss: 0.6201
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6597 - loss: 0.6259 - val_accuracy: 0.7078 - val_loss: 0.6175
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6620 - loss: 0.6443 - val_accuracy: 0.7078 - val_loss: 0.6121
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6669 - loss: 0.6143 - val_accuracy: 0.7208 - val_loss: 0.6155
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6808 - loss: 0.6147 - val_accuracy: 0.7208 - val_loss: 0.6108
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6964 - loss: 0.5924 - val_accuracy: 0.7208 - val_loss: 0.6135
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6831 - loss: 0.5993 - val_accuracy: 0.7208 - val_loss: 0.6080
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7211 - loss: 0.5771 - val_accuracy: 0.6883 - val_loss: 0.6055
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7043 - loss: 0.5930 - val_accuracy: 0.7208 - val_loss: 0.5999
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7165 - loss: 0.5582 - val_accuracy: 0.6883 - val_loss: 0.5969
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7348 - loss: 0.5559 - val_accuracy: 0.7143 - val_loss: 0.5886
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7449 - loss: 0.5433 - val_accuracy: 0.6948 - val_loss: 0.5825
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7379 - loss: 0.5468 - val_accuracy: 0.7143 - val_loss: 0.5789
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7436 - loss: 0.5350 - val_accuracy: 0.7078 - val_loss: 0.5727
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7672 - loss: 0.5150 - val_accuracy: 0.7208 - val_loss: 0.5702
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7813 - loss: 0.5085 - val_accuracy: 0.7273 - val_loss: 0.5639
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7885 - loss: 0.5128 - val_accuracy: 0.7338 - val_loss: 0.5585
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7517 - loss: 0.5021 - val_accuracy: 0.7403 - val_loss: 0.5476
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7867 - loss: 0.4967 - val_accuracy: 0.7468 - val_loss: 0.5423
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7659 - loss: 0.5106 - val_accuracy: 0.7403 - val_loss: 0.5476
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7237 - loss: 0.5462 - val_accuracy: 0.7403 - val_loss: 0.5267
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8211 - loss: 0.4427
# Test Loss: 0.45688942074775696, Test Accuracy: 0.8125
# Model training and saving completed.

# %% [markdown]
# ## Step 3: Make Predictions
#
# Now load your saved model and use it to make predictions on a few random rows in the test dataset. Check if the predictions are correct.

# %%
import numpy as np
import tensorflow as tf

# Step 1: Load the saved model
loaded_model = tf.keras.models.load_model('tic-tac-toe.keras')

# Step 2: Make predictions on a few random rows
random_indices = np.random.choice(X_test.shape[0], size=5, replace=False)
sample_data = X_test[random_indices]
sample_labels = y_test.iloc[random_indices]

predictions = loaded_model.predict(sample_data)
predicted_classes = np.argmax(predictions, axis=1)

# Step 3: Compare predictions with actual labels
for i, index in enumerate(random_indices):
    print(f"Sample {i+1}:")
    print(f"Actual Label: {sample_labels.iloc[i]}, Predicted Label: {predicted_classes[i]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Sample 1:
# Actual Label: 1, Predicted Label: 1
# Sample 2:
# Actual Label: 1, Predicted Label: 1
# Sample 3:
# Actual Label: 1, Predicted Label: 1
# Sample 4:
# Actual Label: 0, Predicted Label: 0
# Sample 5:
# Actual Label: 1, Predicted Label: 1

# %% [markdown]
# ## Step 4: Improve Your Model
#
# Did your model achieve low loss (<0.1) and high accuracy (>0.95)? If not, try to improve your model.
#
# But how? There are so many things you can play with in Tensorflow and in the next challenge you'll learn about these things. But in this challenge, let's just do a few things to see if they will help.
#
# * Add more layers to your model. If the data are complex you need more layers. But don't use more layers than you need. If adding more layers does not improve the model performance you don't need additional layers.
# * Adjust the learning rate when you compile the model. This means you will create a custom `tf.keras.optimizers.Adam` instance where you specify the learning rate you want. Then pass the instance to `model.compile` as the optimizer.
#     * `tf.keras.optimizers.Adam` [reference](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam).
#     * Don't worry if you don't understand what the learning rate does. You'll learn about it in the next challenge.
# * Adjust the number of epochs when you fit the training data to the model. Your model performance continues to improve as you train more epochs. But eventually it will reach the ceiling and the performance will stay the same.

# %%
from tensorflow.keras.optimizers import Adam

# Step 1: Modify the model with additional layers
improved_model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(2, activation='softmax')  # Assuming binary classification
])

# Step 2: Adjust the learning rate
custom_optimizer = Adam(learning_rate=0.001)

# Step 3: Compile the improved model
improved_model.compile(optimizer=custom_optimizer, 
                       loss='sparse_categorical_crossentropy', 
                       metrics=['accuracy'])

# Step 4: Fit the training data with more epochs
improved_model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2)

# Step 5: Evaluate the improved model
test_loss, test_accuracy = improved_model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

# Step 6: Save the improved model
improved_model.save('tic-tac-toe-improved.keras')

print("Improved model training and saving completed.")
# Out:
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6212 - loss: 0.6615 - val_accuracy: 0.6818 - val_loss: 0.6175
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6596 - loss: 0.6235 - val_accuracy: 0.6948 - val_loss: 0.6190
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6812 - loss: 0.6063 - val_accuracy: 0.7013 - val_loss: 0.6079
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9744 - loss: 0.1228 - val_accuracy: 0.8831 - val_loss: 0.3490
# Epoch 36/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9662 - loss: 0.1218 - val_accuracy: 0.8701 - val_loss: 0.3495
# Epoch 37/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9698 - loss: 0.1080 - val_accuracy: 0.8701 - val_loss: 0.3269
# Epoch 38/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9763 - loss: 0.0949 - val_accuracy: 0.8442 - val_loss: 0.5436
# Epoch 39/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9602 - loss: 0.1102 - val_accuracy: 0.8506 - val_loss: 0.3669
# Epoch 40/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9866 - loss: 0.0748 - val_accuracy: 0.8766 - val_loss: 0.3752
# Epoch 41/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9361 - loss: 0.1275 - val_accuracy: 0.8636 - val_loss: 0.3560
# Epoch 42/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0923 - val_accuracy: 0.8636 - val_loss: 0.5014
# Epoch 43/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9726 - loss: 0.0851 - val_accuracy: 0.8636 - val_loss: 0.4215
# Epoch 44/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0691 - val_accuracy: 0.8701 - val_loss: 0.3761
# Epoch 45/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9796 - loss: 0.0704 - val_accuracy: 0.8701 - val_loss: 0.3704
# Epoch 46/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9891 - loss: 0.0658 - val_accuracy: 0.8377 - val_loss: 0.6238
# Epoch 47/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9497 - loss: 0.1052 - val_accuracy: 0.8701 - val_loss: 0.4003
# Epoch 48/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9929 - loss: 0.0507 - val_accuracy: 0.8636 - val_loss: 0.4336
# Epoch 49/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0450 - val_accuracy: 0.8636 - val_loss: 0.4304
# Epoch 50/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9979 - loss: 0.0407 - val_accuracy: 0.8701 - val_loss: 0.3347
# Epoch 51/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0391 - val_accuracy: 0.8766 - val_loss: 0.3734
# Epoch 52/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9984 - loss: 0.0366 - val_accuracy: 0.8831 - val_loss: 0.4217
# Epoch 53/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0349 - val_accuracy: 0.8896 - val_loss: 0.4088
# Epoch 54/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0290 - val_accuracy: 0.8831 - val_loss: 0.3844
# Epoch 55/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 0.0322 - val_accuracy: 0.8831 - val_loss: 0.4096
# Epoch 56/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0255 - val_accuracy: 0.8961 - val_loss: 0.3613
# Epoch 57/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 0.8896 - val_loss: 0.4205
# Epoch 58/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.8961 - val_loss: 0.4081
# Epoch 59/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.8831 - val_loss: 0.4256
# Epoch 60/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 0.8766 - val_loss: 0.4218
# Epoch 61/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.9026 - val_loss: 0.4177
# Epoch 62/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0168 - val_accuracy: 0.8831 - val_loss: 0.4648
# Epoch 63/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.8831 - val_loss: 0.4471
# Epoch 64/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.8831 - val_loss: 0.4223
# Epoch 65/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.8831 - val_loss: 0.4606
# Epoch 66/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.8766 - val_loss: 0.4810
# Epoch 67/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.8701 - val_loss: 0.4813
# Epoch 68/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.8961 - val_loss: 0.4549
# Epoch 69/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.8896 - val_loss: 0.4711
# Epoch 70/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.8896 - val_loss: 0.4329
# Epoch 71/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.8961 - val_loss: 0.3871
# Epoch 72/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.8896 - val_loss: 0.5098
# Epoch 73/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.8961 - val_loss: 0.4675
# Epoch 74/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8766 - val_loss: 0.5109
# Epoch 75/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.8896 - val_loss: 0.4466
# Epoch 76/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9026 - val_loss: 0.4781
# Epoch 77/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.8961 - val_loss: 0.4669
# Epoch 78/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.8961 - val_loss: 0.4149
# Epoch 79/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.8896 - val_loss: 0.5008
# Epoch 80/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9026 - val_loss: 0.4394
# Epoch 81/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8896 - val_loss: 0.4602
# Epoch 82/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.8961 - val_loss: 0.4829
# Epoch 83/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9091 - val_loss: 0.4480
# Epoch 84/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8961 - val_loss: 0.5112
# Epoch 85/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8961 - val_loss: 0.4877
# Epoch 86/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9026 - val_loss: 0.4619
# Epoch 87/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8961 - val_loss: 0.4983
# Epoch 88/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.8896 - val_loss: 0.5452
# Epoch 89/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9091 - val_loss: 0.4648
# Epoch 90/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8961 - val_loss: 0.5056
# Epoch 91/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9091 - val_loss: 0.4829
# Epoch 92/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8961 - val_loss: 0.4903
# Epoch 93/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9026 - val_loss: 0.4982
# Epoch 94/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9026 - val_loss: 0.5066
# Epoch 95/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8961 - val_loss: 0.5237
# Epoch 96/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9091 - val_loss: 0.4752
# Epoch 97/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9091 - val_loss: 0.4945
# Epoch 98/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9091 - val_loss: 0.4665
# Epoch 99/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8961 - val_loss: 0.5278
# Epoch 100/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9091 - val_loss: 0.4955
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9515 - loss: 0.2713
# Test Loss: 0.4055294096469879, Test Accuracy: 0.9270833134651184
# Improved model training and saving completed.

# %% [markdown]
# **Which approach(es) did you find helpful to improve your model performance?**

# %% [raw]
# 1. Adding additional layers improved the model's ability to capture complex patterns in the data.
# 2. Adjusting the learning rate helped optimize the training process by finding a better balance between convergence speed and accuracy.
# 3. Increasing the number of epochs allowed the model to train for a longer duration, improving its ability to generalize and reduce the loss further.
